# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import numpy as np 
from bs4 import BeautifulSoup 
import requests
from IPython.display import Image
from IPython.core.display import HTML

# %%
#Essentially what this cell is doing is getting the HTML from the specific link 
url = 'https://en.wikipedia.org/wiki/List_of_world_records_in_swimming'
page = requests.get(url)
html_text = BeautifulSoup(page.text, "html") #gets the actual HTML text from the website

# %% [markdown]
# # This is a title haha. Remember to make this a markdown cell and use '#'
#
# ## This is a subtitle. Use '##'
#
# ### This is a subsubtitle. Use '###"
#
# "<.br>" you can also use to <br> add line breaks (without the period of course)

# %% [markdown]
# # Getting all the HTML text for our specific table.
#
# Both of the methods below accomplish the same thing. <br>
# Recall that __find( )__ returns the first instance, and __find_all( )__ returns a list of all instance

# %%
table = html_text.find_all("table", class_ = "wikitable sortable") #or
table = html_text.find_all("table")[0]

# %% [markdown]
# ## Getting all the titles of our columns

# %%
col_titles = table.find_all("th")
col_titles
# Out:
# [<th>Event
#  </th>,
#  <th class="unsortable" style="width:4em">Time
#  </th>,
#  <th class="unsortable">
#  </th>,
#  <th>Name</th>,
#  <th>Nationality</th>,
#  <th>Date</th>,
#  <th>Meet</th>,
#  <th>Location
#  </th>,
#  <th class="unsortable" style="width:2em">Ref
#  </th>]

# %% [markdown]
# ### Removes all the excess HTML stuff syntax, and gives us column values which are actually string values

# %%
col_titles = [col_title.text.strip() for col_title in table.find_all("th")]
col_titles
# Out:
# ['Event', 'Time', '', 'Name', 'Nationality', 'Date', 'Meet', 'Location', 'Ref']

# %% [markdown]
# ## Adds all our column titles to the dataframe

# %%
swimming_world_record_data_frame = pd.DataFrame(columns = col_titles)
swimming_world_record_data_frame
# Out:
# Empty DataFrame
# Columns: [Event, Time, , Name, Nationality, Date, Meet, Location, Ref]
# Index: []

# %% [markdown]
# ### In the wikipedia table, each row is divided by its "<.tr>" tag. Thus, by finding all the "<.tr>" tags we get all the HTML for each row

# %%
all_row_values = table.find_all("tr")
all_row_values[1]
# Out:
# <tr>
# <td><span data-sort-value="01  !"> <a href="/wiki/World_record_progression_50_metres_freestyle" title="World record progression 50 metres freestyle">50m freestyle</a> </span>
# </td>
# <td style="text-align:right; padding-left:0.5em; padding-right:0.5em;">20.91
# </td>
# <td style="font-size:smaller">ss</td>
# <td><span class="nowrap"><span data-sort-value="Cielo, César"><span class="vcard"><span class="fn"><a href="/wiki/C%C3%A9sar_Cielo" title="César Cielo">César Cielo</a></span></span></span></span>
# </td>
# <td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><span><img alt="" class="mw-file-element" data-file-height="504" data-file-width="720" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/0/05/Flag_of_Brazil.svg/22px-Flag_of_Brazil.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/0/05/Flag_of_Brazil.svg/33px-Flag_of_Brazil.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/0/05/Flag_of_Brazil.svg/43px-Flag_of_Brazil.svg.png 2x" width="22"/></span></span> </span>Brazil
# </td>
# <td style="text-align:center">18 December 2009</td>
# <td>Brazilian Championships
# </td>
# <td><span data-sort-value="Brazil, São Paulo !"> <a href="/wiki/S%C3%A3o_Paulo" title="São Paulo">São Paulo</a>, Brazil</span>
# </td>
# <td style="text-align:center"><sup class="reference" id="cite_ref-9"><a href="#cite_note-9">[9]</a></sup><sup class="reference" id="cite_ref-10"><a href="#cite_note-10">[10]</a></sup><sup class="reference" id="cite_ref-11"><a href="#cite_note-11">[11]</a></sup><sup class="reference" id="cite_ref-12"><a href="#cite_note-12">[12]</a></sup>
# </td></tr>

# %% [markdown]
# ### We use list comprehension to get all the HTMl within each row, by using its <.td> as each item in the list
#
# The first row is empty, that's why we get all the items from the first index and on
#
# We add all the (cleaned) string representations from each row and add it to the row index of our data frame.
#
# Recall that __.loc( )__ is used to locate a certain row or column in the dataframe. The default is row.

# %%
for specific_row in all_row_values[1:]: 
    specific_row_data = specific_row.find_all('td')
    individual_row_data = [col_in_row.text.strip() for col_in_row in specific_row_data]
    
    length = len(swimming_world_record_data_frame)
    swimming_world_record_data_frame.loc[length] = individual_row_data

# %%
swimming_world_record_data_frame
# Out:
#                         Event      Time         \
# 0               50m freestyle     20.91     ss
# 1              100m freestyle     46.86
# 2              200m freestyle   1:42.00     ss
# 3              400m freestyle   3:40.07     ss
# 4              800m freestyle   7:32.12     ss
# 5             1500m freestyle  14:31.02
# 6              50m backstroke     23.71
# 7              50m backstroke     23.55  sf, #
# 8             100m backstroke     51.60
# 9             200m backstroke   1:51.92     ss
# 10           50m breaststroke     25.95     sf
# 11          100m breaststroke     56.88     sf
# 12          200m breaststroke   2:05.48
# 13              50m butterfly     22.27
# 14             100m butterfly     49.45
# 15             200m butterfly   1:50.34
# 16     200m individual medley   1:54.00
# 17     400m individual medley   4:02.50
# 18  4 × 100 m freestyle relay   3:08.24     ss
# 19  4 × 200 m freestyle relay   6:58.55     ss
# 20     4 × 100 m medley relay   3:26.78
#
#                                                  Name    Nationality  \
# 0                                         César Cielo         Brazil
# 1                                      David Popovici        Romania
# 2                                     Paul Biedermann        Germany
# 3                                     Paul Biedermann        Germany
# 4                                           Zhang Lin          China
# 5                                            Sun Yang          China
# 6                                    Hunter Armstrong  United States
# 7                                  Kliment Kolesnikov         Russia
# 8                                       Thomas Ceccon          Italy
# 9                                       Aaron Peirsol  United States
# 10                                         Adam Peaty  Great Britain
# 11                                         Adam Peaty  Great Britain
# 12                                        Qin Haiyang          China
# 13                                     Andriy Govorov        Ukraine
# 14                                     Caeleb Dressel  United States
# 15                                      Kristóf Milák        Hungary
# 16                                        Ryan Lochte  United States
# 17                                      Léon Marchand         France
# 18  Michael Phelps (47.51)Garrett Weber-Gale (47.0...  United States
# 19  Michael Phelps (1:44.49)Ricky Berens (1:44.13)...  United States
# 20  Ryan Murphy (52.31)Michael Andrew (58.49)Caele...  United States
#
#                 Date                            Meet  \
# 0   18 December 2009         Brazilian Championships
# 1     13 August 2022          European Championships
# 2       28 July 2009             World Championships
# 3       26 July 2009             World Championships
# 4       29 July 2009             World Championships
# 5      4 August 2012                   Olympic Games
# 6      28 April 2022  U.S. International Team Trials
# 7       27 July 2023                     Russian Cup
# 8       20 June 2022             World Championships
# 9       31 July 2009             World Championships
# 10      25 July 2017             World Championships
# 11      21 July 2019             World Championships
# 12      28 July 2023             World Championships
# 13       1 July 2018              Sette Colli Trophy
# 14      31 July 2021                   Olympic Games
# 15      21 June 2022             World Championships
# 16      28 July 2011             World Championships
# 17      23 July 2023             World Championships
# 18    11 August 2008                   Olympic Games
# 19      31 July 2009             World Championships
# 20     1 August 2021                   Olympic Games
#
#                      Location              Ref
# 0           São Paulo, Brazil  [9][10][11][12]
# 1                 Rome, Italy         [13][14]
# 2                 Rome, Italy     [15][16][17]
# 3                 Rome, Italy     [18][19][20]
# 4                 Rome, Italy         [21][22]
# 5      London, United Kingdom         [23][24]
# 6   Greensboro, United States         [25][26]
# 7               Kazan, Russia             [27]
# 8           Budapest, Hungary         [29][30]
# 9                 Rome, Italy     [31][32][33]
# 10          Budapest, Hungary         [34][35]
# 11       Gwangju, South Korea         [36][37]
# 12             Fukuoka, Japan        [38] [39]
# 13                Rome, Italy         [40][41]
# 14               Tokyo, Japan         [42][43]
# 15          Budapest, Hungary         [44][45]
# 16            Shanghai, China     [46][47][48]
# 17             Fukuoka, Japan        [49] [50]
# 18             Beijing, China     [51][52][53]
# 19                Rome, Italy         [54][55]
# 20               Tokyo, Japan             [56]

# %% [markdown]
# ## Cleaning our data a bit more
#
# Dropping the column with 'ss' and the references. We can get rid of these by using the __.drop( )__ method in pandas. Then we specify the columns we want to get rid of. Remember that axis = 1 indicates columns, not rows

# %%
swimming_world_record_data_frame = swimming_world_record_data_frame.drop(swimming_world_record_data_frame.columns[[2,8]], axis = 1)
swimming_world_record_data_frame = swimming_world_record_data_frame.rename(columns = {"Date": "Date Set"})
swimming_world_record_data_frame
# Out:
#                         Event      Time  \
# 0               50m freestyle     20.91
# 1              100m freestyle     46.86
# 2              200m freestyle   1:42.00
# 3              400m freestyle   3:40.07
# 4              800m freestyle   7:32.12
# 5             1500m freestyle  14:31.02
# 6              50m backstroke     23.71
# 7              50m backstroke     23.55
# 8             100m backstroke     51.60
# 9             200m backstroke   1:51.92
# 10           50m breaststroke     25.95
# 11          100m breaststroke     56.88
# 12          200m breaststroke   2:05.48
# 13              50m butterfly     22.27
# 14             100m butterfly     49.45
# 15             200m butterfly   1:50.34
# 16     200m individual medley   1:54.00
# 17     400m individual medley   4:02.50
# 18  4 × 100 m freestyle relay   3:08.24
# 19  4 × 200 m freestyle relay   6:58.55
# 20     4 × 100 m medley relay   3:26.78
#
#                                                  Name    Nationality  \
# 0                                         César Cielo         Brazil
# 1                                      David Popovici        Romania
# 2                                     Paul Biedermann        Germany
# 3                                     Paul Biedermann        Germany
# 4                                           Zhang Lin          China
# 5                                            Sun Yang          China
# 6                                    Hunter Armstrong  United States
# 7                                  Kliment Kolesnikov         Russia
# 8                                       Thomas Ceccon          Italy
# 9                                       Aaron Peirsol  United States
# 10                                         Adam Peaty  Great Britain
# 11                                         Adam Peaty  Great Britain
# 12                                        Qin Haiyang          China
# 13                                     Andriy Govorov        Ukraine
# 14                                     Caeleb Dressel  United States
# 15                                      Kristóf Milák        Hungary
# 16                                        Ryan Lochte  United States
# 17                                      Léon Marchand         France
# 18  Michael Phelps (47.51)Garrett Weber-Gale (47.0...  United States
# 19  Michael Phelps (1:44.49)Ricky Berens (1:44.13)...  United States
# 20  Ryan Murphy (52.31)Michael Andrew (58.49)Caele...  United States
#
#             Date Set                            Meet  \
# 0   18 December 2009         Brazilian Championships
# 1     13 August 2022          European Championships
# 2       28 July 2009             World Championships
# 3       26 July 2009             World Championships
# 4       29 July 2009             World Championships
# 5      4 August 2012                   Olympic Games
# 6      28 April 2022  U.S. International Team Trials
# 7       27 July 2023                     Russian Cup
# 8       20 June 2022             World Championships
# 9       31 July 2009             World Championships
# 10      25 July 2017             World Championships
# 11      21 July 2019             World Championships
# 12      28 July 2023             World Championships
# 13       1 July 2018              Sette Colli Trophy
# 14      31 July 2021                   Olympic Games
# 15      21 June 2022             World Championships
# 16      28 July 2011             World Championships
# 17      23 July 2023             World Championships
# 18    11 August 2008                   Olympic Games
# 19      31 July 2009             World Championships
# 20     1 August 2021                   Olympic Games
#
#                      Location
# 0           São Paulo, Brazil
# 1                 Rome, Italy
# 2                 Rome, Italy
# 3                 Rome, Italy
# 4                 Rome, Italy
# 5      London, United Kingdom
# 6   Greensboro, United States
# 7               Kazan, Russia
# 8           Budapest, Hungary
# 9                 Rome, Italy
# 10          Budapest, Hungary
# 11       Gwangju, South Korea
# 12             Fukuoka, Japan
# 13                Rome, Italy
# 14               Tokyo, Japan
# 15          Budapest, Hungary
# 16            Shanghai, China
# 17             Fukuoka, Japan
# 18             Beijing, China
# 19                Rome, Italy
# 20               Tokyo, Japan

# %% [markdown]
# ### Yay!!!! We have sucessfully webscraped a table from wikipedia and turned it into a dataframe!
#
# I got the idea from Alex the Analyst on YouTube. Here's the [link!](https://www.youtube.com/watch?v=8dTpNajxaH0&list=LL&index=1&t) to his video :)
